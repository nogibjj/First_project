# %%
import pandas as pd
import matplotlib.pyplot as plt
import markdownify as md

# %%
FILE_PATH = "NBA_24_stats.csv"
df = pd.read_csv(FILE_PATH)

# %%
def summary():
    """provides summary statistics"""
    summary_stats = df.describe()
    print(summary_stats)

# %%
def points_plot():
    """provides visualization"""
    accurate = df[df["3P%"] >= 0.5]
    player_rank = accurate["Player"].astype(str)
    plt.barh(player_rank, width=accurate["PTS"], color="green")
    plt.xlabel("PPG")
    plt.ylabel("Players")
    plt.title("PPG for Players with 50% or higher 3P%")
    plt.subplots_adjust(left=0.25)
    plt.savefig("NBA_pts_bar.png")
    plt.show()

# %%
points_plot()
summary()
# Out:
#               Age           G          GS          MP          FG         FGA  \
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean    26.155102   40.880272   18.440816   18.264762    2.972789    6.423401
# std      4.371745   25.581293   25.024108    9.735524    2.356999    4.783384
# min     19.000000    1.000000    0.000000    0.500000    0.000000    0.000000
# 25%     23.000000   17.000000    0.000000   10.600000    1.300000    3.000000
# 50%     25.000000   41.000000    5.000000   17.200000    2.300000    5.000000
# 75%     29.000000   64.500000   29.000000   26.450000    4.150000    8.700000
# max     39.000000   84.000000   82.000000   37.800000   11.500000   23.600000
#
#               FG%          3P         3PA         3P%  ...         FT%  \
# count  728.000000  735.000000  735.000000  690.000000  ...  677.000000
# mean     0.447595    0.909116    2.582449    0.316996  ...    0.749721
# std      0.110629    0.848969    2.166629    0.137130  ...    0.159918
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.400000    0.200000    0.900000    0.280250  ...    0.686000
# 50%      0.446500    0.700000    2.100000    0.346000  ...    0.778000
# 75%      0.500000    1.400000    3.700000    0.385000  ...    0.840000
# max      0.800000    4.800000   11.800000    1.000000  ...    1.000000
#
#               ORB         DRB         TRB         AST         STL         BLK  \
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean     0.822041    2.423265    3.239184    1.934150    0.587347    0.383946
# std      0.732770    1.741203    2.320766    1.800255    0.393774    0.400733
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.300000    1.100000    1.600000    0.700000    0.300000    0.100000
# 50%      0.600000    2.100000    2.800000    1.300000    0.500000    0.300000
# 75%      1.100000    3.350000    4.300000    2.600000    0.800000    0.500000
# max      4.600000   10.100000   13.700000   10.900000    2.100000    3.600000
#
#               TOV          PF         PTS
# count  735.000000  735.000000  735.000000
# mean     0.943946    1.456735    8.022313
# std      0.758414    0.784284    6.481825
# min      0.000000    0.000000    0.000000
# 25%      0.400000    0.900000    3.400000
# 50%      0.700000    1.400000    6.100000
# 75%      1.300000    2.000000   11.050000
# max      4.400000    3.600000   34.700000
#
# [8 rows x 26 columns]
